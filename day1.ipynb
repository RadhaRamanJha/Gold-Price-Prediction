# %%
print("Hello")

# %%
a=6

# %%
type(a)

# %%
b=1.2

# %%
type(b)

# %%
a+b

# %%
a-b

# %%
a/b

# %%
a//b

# %%
a%b

# %%
a*b

# %%
a or b

# %%
a and b

# %%
a,b

# %%
a b

# %%
 a

# %%
a<b and a>1

# %%
a=10
b=4

# %%
a>b and b<5

# %%
l1=['hello','hi','hey']

# %%
l1

# %%
list1=[10,20,30,40,100,60,70,80,90]

# %%
list1[-2:-7]

# %%
list1[-7:-2]

# %%
sort[list1]

# %%
revers[list1]

# %%
list1.sort()
list1
list1.sort(reverse=True)
list1

# %%
l3=['ram','raja','rahul','ragav']

# %%
for x in l3:
    print(x)
    print("_______________")

# %%
pip install pyspark

# %%
from pyspark.sql import SparkSession

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.seasonal import STL

# %%
gold_d=pd.read_csv("Gold_Price_in_India_for_Project.csv",parse_dates=['Date'])

# %%
gold_d
# Out:
#              Date  Indian rupee (INR)
# 0      02-01-1979             1792.85
# 1      03-01-1979             1802.15
# 2      04-01-1979             1811.74
# 3      05-01-1979             1843.57
# 4      08-01-1979             1841.33
# ...           ...                 ...
# 11284  04-04-2022           145834.17
# 11285  05-04-2022           146459.87
# 11286  06-04-2022           146223.33
# 11287  07-04-2022           146780.27
# 11288  08-04-2022           147381.37
#
# [11289 rows x 2 columns]

# %%
gold_d.info
# Out:
# <bound method DataFrame.info of              Date  Indian rupee (INR)
# 0      02-01-1979             1792.85
# 1      03-01-1979             1802.15
# 2      04-01-1979             1811.74
# 3      05-01-1979             1843.57
# 4      08-01-1979             1841.33
# ...           ...                 ...
# 11284  04-04-2022           145834.17
# 11285  05-04-2022           146459.87
# 11286  06-04-2022           146223.33
# 11287  07-04-2022           146780.27
# 11288  08-04-2022           147381.37
#
# [11289 rows x 2 columns]>

# %%
gold_d =gold_d.set_index(pd.DatetimeIndex(gold_d['Date'])).drop('Date',axis=1)

# %%
gold_d.isna().sum()
# Out:
# Indian rupee (INR)    0
# dtype: int64

# %%
gold_d.dtypes
# Out:
# Indian rupee (INR)    float64
# dtype: object

# %%
gold_d["Date"]=pd.to_numeric(gold_d["Date"],errors="coerce")

# %%
gold_d.dtypes
# Out:
# Date                  float64
# Indian rupee (INR)    float64
# dtype: object

# %%
gold_d = gold_d.rename(columns = {"Indian rupee (INR)":"Inr"})

# %%
gold_d.shape
# Out:
# (11289, 1)

# %%
sns.boxplot(gold_d["Inr"])
# Out:
# <Axes: >

# %%
pip install sweetviz

# %%
import sweetviz as sv

# %%
sv_report = sv.analyze(gold_d)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
sv_report.show_html("eda_report8.html")
# Out:
# Report eda_report8.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
sns.histplot(gold_d["Inr"],cumulative=True)
# Out:
# <Axes: xlabel='Inr', ylabel='Count'>

# %%
print(f"The Gold prices are available for {gold_d.index.year.max() - gold_d.index.year.min()} years")
# Out:
# The Gold prices are available for 43 years

# %%
pip install calplot

# %%
import calplot

# %%
calplot.calplot(gold_d['Inr'], edgecolor='none', yearlabel_kws={'fontname': 'sans-serif'})
# Out:
# (<Figure size 1250x7480 with 45 Axes>,
#  array([<Axes: ylabel='1979'>, <Axes: ylabel='1980'>,
#         <Axes: ylabel='1981'>, <Axes: ylabel='1982'>,
#         <Axes: ylabel='1983'>, <Axes: ylabel='1984'>,
#         <Axes: ylabel='1985'>, <Axes: ylabel='1986'>,
#         <Axes: ylabel='1987'>, <Axes: ylabel='1988'>,
#         <Axes: ylabel='1989'>, <Axes: ylabel='1990'>,
#         <Axes: ylabel='1991'>, <Axes: ylabel='1992'>,
#         <Axes: ylabel='1993'>, <Axes: ylabel='1994'>,
#         <Axes: ylabel='1995'>, <Axes: ylabel='1996'>,
#         <Axes: ylabel='1997'>, <Axes: ylabel='1998'>,
#         <Axes: ylabel='1999'>, <Axes: ylabel='2000'>,
#         <Axes: ylabel='2001'>, <Axes: ylabel='2002'>,
#         <Axes: ylabel='2003'>, <Axes: ylabel='2004'>,
#         <Axes: ylabel='2005'>, <Axes: ylabel='2006'>,
#         <Axes: ylabel='2007'>, <Axes: ylabel='2008'>,
#         <Axes: ylabel='2009'>, <Axes: ylabel='2010'>,
#         <Axes: ylabel='2011'>, <Axes: ylabel='2012'>,
# ...

# %%
gold_d.plot(figsize = (15,5))
plt.xlabel("Observation Date")
plt.ylabel("Prices")
plt.title("Gold Prices over Time")
plt.show()

# %%
gold_d.plot(xlim = ['2021-08-21','2021-12-21'],ls='--', c='g',ylim = [100000,150000],figsize = (15,5))
plt.xlabel("Observation Date")
plt.ylabel("Prices")
plt.title("Gold Prices in Last Four months")
plt.show()

# %%
last_4month_index = gold_d.loc['2021-08-21':'2021-12-21'].index
last_4month_price = gold_d.loc['2021-08-21':'2021-12-21']['Inr']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 last_4month_index = gold_d.loc['2021-08-21':'2021-12-21'].index
#       2 last_4month_price = gold_d.loc['2021-08-21':'2021-12-21']['Inr']
#
# File C:\Users\kotiv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\Users\kotiv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1323, in _LocIndexer._getitem_axis(self, key, axis)
#    1321 if isinstance(key, slice):
#    1322     self._validate_key(key, axis)
# -> 1323     return self._get_slice_axis(key, axis=axis)
#    1324 elif com.is_bool_indexer(key):
#    1325     return self._getbool_axis(key, axis=axis)
#
# ...

# %%
figure,ax = plt.subplots(figsize = (15,5))
plt.tight_layout()
figure.autofmt_xdate()
ax.plot(last_4month_index,last_4month_price)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2 plt.tight_layout()
#       3 figure.autofmt_xdate()
# ----> 4 ax.plot(last_4month_index,last_4month_price)
#       5 plt.show()
#
# NameError: name 'last_4month_index' is not defined

# %%
_,ax = plt.subplots(figsize=(25,25))
sns.boxplot(x=gold_d.index.year, y = gold_d.Inr,ax=ax)
plt.title("Box Plot of Gold Prices from 2016 to 2021")
plt.xlabel("Year")
plt.ylabel("Gold Prices")
plt.show()
